# %%
from coba.benchmarks import Result

# %%
result = Result.from_transaction_log('benchmark_medish_noise.log')
print(result)
result.standard_plot()
# Out:
# {'Learners': 18, 'Simulations': 9, 'Batches': 161676}
# <img src="data:image/png;base64,..." width="1200">

# %%
l,s,b = result.to_pandas()
l.sort_values(by='p')
# Out:
#     learner_id                           family  \
# 0            0                     CMT_Residual
# 1            1                            CMT_1
# 2            2                     CMT_Residual
# 3            3                            CMT_1
# 4            4  vw_cb_explore_adf_epsilongreedy
# 5            5                       bandit_UCB
# 11          11                       bandit_UCB
# 10          10  vw_cb_explore_adf_epsilongreedy
# 9            9                            CMT_1
# 8            8                     CMT_Residual
# 7            7                            CMT_1
# 6            6                     CMT_Residual
# 12          12                     CMT_Residual
# 13          13                            CMT_1
# 14          14                     CMT_Residual
# 15          15                            CMT_1
# 16          16  vw_cb_explore_adf_epsilongreedy
# 17          17                       bandit_UCB
#
# ...

# %%
# %matplotlib notebook
result.standard_plot([1,3,7,9,13,15])
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
# %matplotlib notebook
result.standard_plot([0,2,6,8,12,14])
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
# %matplotlib notebook
result.standard_plot([0,1,2,3,4,5])
# Out:
# <img src="data:image/png;base64,..." width="1200">

# %%
# %matplotlib notebook
result.standard_plot([6,7,8,9,10,11])
# Out:
# <img src="data:image/png;base64,..." width="1320">

# %%
# %matplotlib notebook
result.standard_plot([12,13,14,15,16,17])
# Out:
# <img src="data:image/png;base64,..." width="1199.999930641872">
